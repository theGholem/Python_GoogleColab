# %%
print('Hello')
# Out:
# Hello

# %%
import pandas as pd

# %% [markdown]
# /**Pour installer une bibliotheque */
#
# !pip install nomDeLaBibliotheque

# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.15.0'

# %%
tf.__version__
# Out:
# '2.15.0'

# %%
myList=[1,2,3,4,5]
